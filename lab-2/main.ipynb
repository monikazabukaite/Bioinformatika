# %%
pip install ete3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ete3 import Tree

# %%
camel_virus = 'MT085175.1'

# %%
generated = Tree('generatedTree.txt', format=1)

# %%
print("Prieš:")
print(generated)
# Out:
# Before:
#
#    /-SARScoronavirusHZS2-D
#   |
#   |--SARScoronavirusSino3-11
#   |
#   |   /-SARScoronavirusHZS2-C
#   |  |
#   |  |   /-SARScoronavirusHKU-39849isolateUOB
#   |  |  |
#   |  |  |               /-SARScoronavirusBJ182-12
#   |  |  |              |
#   |  |  |            /-|   /-SARScoronavirusBJ182-4
#   |  |  |           |  |  |
#   |  |  |           |  |  |--SARScoronavirusBJ182a
#   |  |  |           |   \-|
#   |  |  |           |     |--SARScoronavirusBJ182b
#   |  |  |           |     |
# --|  |  |           |      \-SARScoronavirusBJ182-8
#   |  |  |           |
#   |  |  |         /-|      /-SARScoronavirusGZ02
#   |  |  |        |  |   /-|
#   |  |  |        |  |  |  |   /-SARScoronavirusSZ3
#   |  |  |        |  |  |   \-|
#   |  |  |        |  |  |      \-SARScoronavirusSZ16
#   |  |  |        |  |  |
#   |  |  |        |  |  |      /-SARScoronavirusZS-B
#   |  |  |        |  |  |   /-|
#   |  |  |        |  |  |  |   \-SARScoronavirusZS-C
# ...

# %%
generated.set_outgroup(camel_virus)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/jb/t_lrz0x16yb4d596rz8b7svh0000gn/T/ipykernel_4409/1861646397.py in <module>
# ----> 1 generated.set_outgroup(camel_virus)
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ete3/coretype/tree.py in set_outgroup(self, outgroup)
#    1251         """
#    1252
# -> 1253         outgroup = _translate_nodes(self, outgroup)
#    1254
#    1255         if self == outgroup:
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ete3/coretype/tree.py in _translate_nodes(root, *nodes)
#    2599     if None in list(name2node.values()):
#    2600         notfound = [key for key, value in six.iteritems(name2node) if value is None]
# -> 2601         raise ValueError("Node names not found: "+str(notfound))
#    2602
#    2603     valid_nodes = []
#
# ...

# %%
print("Po:")
print(generated)
# Out:
# After:
#
#    /-SARScoronavirusHZS2-D
#   |
#   |--SARScoronavirusSino3-11
#   |
#   |   /-SARScoronavirusHZS2-C
#   |  |
#   |  |   /-SARScoronavirusHKU-39849isolateUOB
#   |  |  |
#   |  |  |               /-SARScoronavirusBJ182-12
#   |  |  |              |
#   |  |  |            /-|   /-SARScoronavirusBJ182-4
#   |  |  |           |  |  |
#   |  |  |           |  |  |--SARScoronavirusBJ182a
#   |  |  |           |   \-|
#   |  |  |           |     |--SARScoronavirusBJ182b
#   |  |  |           |     |
# --|  |  |           |      \-SARScoronavirusBJ182-8
#   |  |  |           |
#   |  |  |         /-|      /-SARScoronavirusGZ02
#   |  |  |        |  |   /-|
#   |  |  |        |  |  |  |   /-SARScoronavirusSZ3
#   |  |  |        |  |  |   \-|
#   |  |  |        |  |  |      \-SARScoronavirusSZ16
#   |  |  |        |  |  |
#   |  |  |        |  |  |      /-SARScoronavirusZS-B
#   |  |  |        |  |  |   /-|
#   |  |  |        |  |  |  |   \-SARScoronavirusZS-C
# ...
